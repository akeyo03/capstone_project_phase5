# %% [markdown]
# <a href="https://colab.research.google.com/github/akeyo03/capstone_project_phase5/blob/main/README.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SENTIMENTAL ANALYSIS FOR HARMFUL LANGUAGE DETECTION IN TWEETS

# %% [markdown]
# INTRODUCTION

# %% [markdown]
# It is a Natural Language Processing problem where sentimental analysis is done by classyfing the positive and negative tweets thereby contributing to the prevention of cyberbullying in social platforms.
#
# Natural Language Processing is a growing field in data science, and one of the most uses is sentimental analysis.With NLP, we can analyze more than a thousand text documents for sentiment easily something that would take people hours.
#
# Around twenty thousand rows of this dataset are selected and then cleaned.Then we will explore the cleaned text and try to get some intuition about the context of the tweets. After we will extract numerical features from the data and finally use these features to train models and  identify the sentiments of the tweets.

# %% [markdown]
# PROBLEM STATEMENT
#
# In this digital age, social media has become a platform for various interaction, but they also serve an environment where cyberbullying and harmful language can thrive.The ongoing nature of online communication it can lead to some pyschological issues on certain individuals, especially on young people.The goal is to create a system that detects these tweets that filters and reduces exposure to users to foster a safe online environment.

# %% [markdown]
# DATA STEP
#
# KEY STEPS

# %% [markdown]
# 1.DATA AQUISATION:
#
# The data was aquired from Hugging Face Platform curated by David Thompson
#
# 2.DATA CLEANING:
#
# Handling missing values and duplicates.
#
# Removing irrelevant information
#
# Converting texts to lowercase.
#
#
# 3.TEXTS PREPROCESSING:
#
# Removing stopwords(words with little meaning).
#
#
# 4.FEATURE EXTRACTION:
#
# Converting texts unto numerical data using;TF-IDF.
#
#
# 5.MODEL TRAINING:
#
# Assess and imrpove the machine learning models to understand better language and working with sequences of data.
#
#
# 6.MODEL EVALUATION:
#
# Measuring the model accuracy using appropriate metrics.
#
#
# 7.MODEL DEPLOYMENT:

# %% [markdown]
# PREPROCESSING AND CLEANING
#
# In a scenario you looking for a particular file in an office.Where are we most likely to find the file quite easily?Isn't it in the office where the files are well arranged in the documents.This contradicts the data cleaning exercise for if the data is well formatted it is for find the right information.
#
# Preprocessing text data is a crucial step because it  prepares the raw text for analysis, ensuring its ready for machine learning.Without this step, you risk working with messy and inconsistent data.The goal is to remove unnecessary  elements and elements that don't contribute to the understanding of tweets

# %% [markdown]
# EXPLANATORY DATA ANALYSIS
#
# 1.UNIVARIATE ANALYSIS

# %% [markdown]
# DITRIBUTION OF TOTAL COUNTS OF LABELS IN EACH TWEET

# %% [markdown]
# ![Screenshot 2024-11-07 120834.png](data:image/png;base64,...)

# %% [markdown]
# DISTRIBUTION OF HATE SPEECH COUNT

# %% [markdown]
# ![Screenshot 2024-11-07 104633.png](data:image/png;base64,...)

# %% [markdown]
# DISTRIBUTION OF OFFENSIVE LANGUAGE COUNT

# %% [markdown]
# ![Screenshot 2024-11-07 104850.png](data:image/png;base64,...)

# %% [markdown]
# DISTRIBUTION OF NEITHER COUNT

# %% [markdown]
# ![Screenshot 2024-11-07 104924.png](data:image/png;base64,...)

# %% [markdown]
# DISTRIBUTION OF TWEET LENGTH

# %% [markdown]
# ![Screenshot 2024-11-07 105014.png](data:image/png;base64,...)

# %% [markdown]
# 2.BIVARIATE ANALYSIS

# %% [markdown]
# HATE SPEECH COUNT ACROSS CLASSES

# %% [markdown]
# ![Screenshot 2024-11-07 111657.png](data:image/png;base64,...)

# %% [markdown]
# OFFENSIVE LANGUAGE COUNT ACROSS THE CLASSES

# %% [markdown]
# ![Screenshot 2024-11-07 111721.png](data:image/png;base64,...)

# %% [markdown]
# NEITHER COUNT ACROSS CLASSES

# %% [markdown]
# ![Screenshot 2024-11-07 111739.png](data:image/png;base64,...)

# %% [markdown]
# TOTAL COUNT ACROSS CLASSES

# %% [markdown]
# ![Screenshot 2024-11-07 111758.png](data:image/png;base64,...)

# %% [markdown]
# TWEET LENGTH ACROSS CLASSES

# %% [markdown]
# ![Screenshot 2024-11-07 122901.png](data:image/png;base64,...)

# %% [markdown]
# HATE SPEECH COUNT VS OFFENSIVE LANGUAGE COUNT

# %% [markdown]
# ![Screenshot 2024-11-07 123102.png](data:image/png;base64,...)

# %% [markdown]
# HATE SPEECH COUNT VS NEITHER COUNT

# %% [markdown]
# ![Screenshot 2024-11-07 123240.png](data:image/png;base64,...)

# %% [markdown]
# OFFENSIVE LANGUAGE COUNT VS NEITHER COUNT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.MULTIVARIATE ANALYSIS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# END NOTES

# %% [markdown]
# In this article, we learned how to approach the sentimental problem.We started with preprocessing and data cleaning.Then we extracted features from the cleaned text.Finally we were able to build couple of models using the feature to identify harmful comments.
